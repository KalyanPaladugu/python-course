# %%
##### Python
print("Welcome to python revision")
# Out:
# Welcome to python revision

# %%
##### Variable - to store data suing names
name="Kalyan"
age=32
percentge=87.3
print(f"{name} has age of{age}")
# Out:
# Kalyan has age of32

# %%
##### operators in python - arthimetic,comparison,logical,assignment
a=12
b=5
print(a/b)
print(a//b)
print(a%b)

print(a>b)
print(a !=b)

c=True
d=False
print(c and d)  # or ,not
a=a+12
print(a)
# Out:
# 2.4
# 2
# 2
# True
# True
# False
# 24

# %%
##### Typecasting in python   - int() str() , float()

x=12.3
print(type(x))
print(int(x))
x=str(x)
print(type(x))
# Out:
# <class 'float'>
# 12
# <class 'str'>

# %%
######   Input in python -take input from user

x=int(input("Enter a number"))
print(x)
# Out:
# Enter a number 23
# 23

# %%
##### conditional statments -if ,elif, else for decision making
a=int(input("Enter a value"))
b=int(input("Enter b value"))
c=int(input("Enter c value"))
if a>b and a>c:
      print(f"{a} is bigger than {b} and {c}")
elif b>a and b>c:
    print(f"{b} is bigger than {a} and {c}")
else:
    print(f"{c} is bigger than {a} and {b}")
# Out:
# Enter a value 23
# Enter b value 2
# Enter c value 145
# 145 is bigger than 23 and 2

# %%
###### Loops
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,11,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(1,11):
    if i%2==0:
        print("Even number",i)
    else:
        print("odd number",i)
# Out:
# odd number 1
# Even number 2
# odd number 3
# Even number 4
# odd number 5
# Even number 6
# odd number 7
# Even number 8
# odd number 9
# Even number 10

# %%
name="kalyana"
for i in name:
    print(i,end=" ")
# Out:
# k a l y a n a

# %%
##### while loop: repeats block of code unitl condition fail
i=1
while i<=5:
    print("sam")
    i +=1
# Out:
# sam
# sam
# sam
# sam
# sam

# %%
password=""
while password != "kalyan":
    password = input("Enter username")
print("Access Granted")
# Out:
# Enter username kal
# Enter username kalyan
# Access Granted

# %%
#### List in python ordered,changeable collection using []
#### List operators change,append remove,pop clear
numbers=[1,2,1,33,4,5]
# numbers[0]=23 changes list first element
# numbers.append(23) add element at last index [1, 2, 3, 4, 5, 23]
# numbers.remove(3) remove direct element [1, 2, 4, 5]
# numbers.pop(3)  remove element based on index [1, 2, 3, 5]
# numbers.clear()   remove all elelement []
numbers.sort()
print(numbers)
# Out:
# [1, 1, 2, 4, 5, 33]

# %%
#### Tuple in python ordered , unchangeable collection using () and allow duplicate values
#### Tuple operations - count(),index,len(), immutability

numbers=(1,2,3,4,3,2,1,2,5,3,64)
# print(numbers.count(2))  how many time 2 value is repeated
# print(numbers.index(2))  first index position of element
# print(len(numbers))  lenght of tuple
print(numbers)
# Out:
# 11
# (1, 2, 3, 4, 3, 2, 1, 2, 5, 3, 64)

# %%
#### set in ptyhon unordered collection with out duplicate vlues using {}
#### set operations   add,remove,discard,clear, union ,intersection,difference

set1={1,2,3,4,1,2,3}
set1.add(23)
# set1.remove(11)   key error will get if vlue not found
# set1.discard(11) will not throw any error
# print(set1)

a={1,2,6}
b={2,4,5}
# print(a.union(b))   combine all values
# print(a.intersection(b))  print common values
# print(b.difference(a)) print diiferent values in b
# Out:
# {4, 5}

# %%
#### Dictionary in python - key-value pairs ,mutable, unordered
# example student={"name":"kalyan"}

student={"name":"kalyan","Age":20,"section":"B"}
student['name']="Ram"
# student["pho"]=987654321 
# student.pop('pho') remove specific item
# student.popitem()  remove last item
print(student['name'])
print(student.keys())
print(student.values())
# Out:
# Ram
# dict_keys(['name', 'Age', 'section'])
# dict_values(['Ram', 20, 'B'])

# %%
#### Functions in python a block of reusable code using def

# - simple functions
# - paramter function
# - return function

def student():
    print("Welcme to college")

student()

def student(name):
    print("Welcme to college",name)

student("kalyan")

def add(a,b):
    return a+b
a=student("Kalyan")
print(a)
x=add(3,4)
print(x)
# Out:
# Welcme to college
# Welcme to college kalyan
# Welcme to college Kalyan
# None
# 7

# %%
### Function types
        # - default arguments
        # - keyword arguments
        # - multiple return values
        # - list as argument
        # - lambda function

# - default
def student(name="Ram"):
    print("Welcome to vvit college",name)

student("Kalyan")
# student() default argument will activated


# -keyword

def student(age,name):
    print("Welcome to vvit college",name,"and your age is",age)

student(name="Ram",age=23)

# - multiple return

def cal(a,b):
    return a+b,a-b
add,sub=cal(2,3)
print(add,sub)

# - list as argument
list= [1,2,33]
def cal1(list):
    print(sum(list))
cal1(list)

# - lambda function


square=lambda x:x*x

square(3)
# Out:
# Welcome to vvit college Kalyan
# Welcome to vvit college Ram and your age is 23
# 5 -1
# 36
# 9
